# %%
import pandas as pd
from pathlib import Path

# Cargar datos (funciona si corres desde la raíz del repo o desde la carpeta Act2_RegresionLinealMultiple)
path1 = Path("Act2_RegresionLinealMultiple") / "B_CincinnatiPaintCompany.csv"
path2 = Path("B_CincinnatiPaintCompany.csv")

csv_path = path1 if path1.exists() else path2

df = pd.read_csv(csv_path)
df
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/arrays/masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (
#     Commissions  Calls  Driven
# 0            22    139    2371
# 1            13    132    2226
# 2            33    144    2731
# 3            38    142    3351
# 4            23    142    2289
# 5            47    142    3449
# 6            29    138    3114
# 7            38    139    3342
# 8            41    144    2842
# 9            32    134    2625
# 10           20    135    2121
# 11           13    137    2219
# 12           47    146    3463
# 13           38    146    3290
# ...

# %%
# Definir variables (y = dependiente, X = independientes)

y_col = "Commissions"
x_cols = ["Calls", "Driven"]

y = df[y_col]
X = df[x_cols]

print("Variable dependiente (y):", y_col)
print("Variables independientes (X):", ", ".join(x_cols))

# Ajuste del modelo (statsmodels si está disponible; si no, sklearn)
try:
    import statsmodels.api as sm
    from IPython.display import display, Math

    X_sm = sm.add_constant(X)
    model = sm.OLS(y, X_sm).fit()

    display(model.summary())

    b0 = model.params["const"]
    b1 = model.params[x_cols[0]]
    b2 = model.params[x_cols[1]]

    display(Math(
        rf"\\hat{{{y_col}}} = {b0:.4f} + ({b1:.4f})\\,{x_cols[0]} + ({b2:.4f})\\,{x_cols[1]}"
    ))
except Exception:
    from sklearn.linear_model import LinearRegression

    lr = LinearRegression()
    lr.fit(X, y)

    b0 = lr.intercept_
    b1, b2 = lr.coef_

    print("\nEcuación de regresión múltiple (estimada):")
    print(f"{y_col}^ = {b0:.4f} + ({b1:.4f})*{x_cols[0]} + ({b2:.4f})*{x_cols[1]}")
# Out:
# Variable dependiente (y): Commissions
# Variables independientes (X): Calls, Driven
#
# Ecuación de regresión múltiple (estimada):
# Commissions^ = -101.3144 + (0.6323)*Calls + (0.0157)*Driven
